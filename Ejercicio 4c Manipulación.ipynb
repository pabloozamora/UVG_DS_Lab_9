# %% [markdown]
# ### Gráfica manipulada

# %%
import matplotlib.pyplot as plt
import pandas as pd

file_path = 'data/depuracion.csv'
depuracion_data = pd.read_csv(file_path)

# Convertir la columna 'Fecha' en índice para un gráfico más claro
depuracion_data['Fecha'] = pd.to_datetime(depuracion_data['Fecha'], format='%b-%y')
depuracion_data.set_index('Fecha', inplace=True)

# Crear una gráfica engañosa manipulando la escala del eje Y
plt.figure(figsize=(10, 5))
plt.plot(depuracion_data.index, depuracion_data['Ventas Reales (unidades)'], marker='o', color='b')

# Manipular el eje Y con un rango muy estrecho
plt.ylim(43000000, 64000000)

# Títulos y etiquetas
plt.title("Ventas Reales (unidades) - Gráfica Engañosa con Escala Manipulada")
plt.xlabel("Fecha")
plt.ylabel("Ventas Reales (unidades)")

# Mostrar la gráfica
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Gráfica acertada

# %%
import matplotlib.pyplot as plt
import pandas as pd

file_path = 'data/depuracion.csv'
depuracion_data = pd.read_csv(file_path)

# Convertir la columna 'Fecha' en índice para un gráfico más claro
depuracion_data['Fecha'] = pd.to_datetime(depuracion_data['Fecha'], format='%b-%y')
depuracion_data.set_index('Fecha', inplace=True)

# Crear una gráfica engañosa manipulando la escala del eje Y
plt.figure(figsize=(10, 3))
plt.plot(depuracion_data.index, depuracion_data['Ventas Reales (unidades)'], marker='o', color='b')

# Títulos y etiquetas
plt.title("Ventas Reales (unidades) - Gráfica con Escala Adecuada")
plt.xlabel("Fecha")
plt.ylabel("Ventas Reales (unidades)")

# Mostrar la gráfica
plt.tight_layout()
plt.show()
